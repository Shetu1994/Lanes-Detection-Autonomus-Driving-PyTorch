# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Basic Main Variable Declarations
w1=0.1;
w2=-1/38;
bias=0;
delta=0.05;


def sigma_neuron(x,ddt=False):
    if(ddt==True):
        return x*(1-x)
    return 1/(1+np.exp(-x))

def sigmoid(x):
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a




np.random.seed(1232343242);
x = np.random.normal(5, delta, 10);
y = w2*sigma_neuron(w1*x+bias);
Xaxis = np.arange(-10., 10., 0.2)
sig = sigmoid(Xaxis)

plt.figure(figsize=(10,6))
plt.subplot(2,1,1)   
plt.plot(np.arange(len(x)),y)
plt.subplot(2,1,2)
plt.plot(np.arange(len(x)),x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Update by Suraj Khan
# On Saturday, 24 Nov 2018
# Coefficients based on some new theoretical calculation!
#


# Basic Main Variable Declarations
w1=0.1;
w2=-1/38;
bias=0;
data_length_x = 100;


def sigma_neuron(x,ddt=False):
    if(ddt==True):
        return x*(1-x)
    return 1/(1+np.exp(-x))



np.random.seed(1232);

#inputs
#Xaxis = np.arange(-10., 10., 0.2)
x = np.random.random(data_length_x);
ip= x;

y = w2*sigma_neuron((w1*ip+bias));

#print x
#print y
plt.plot(ip,y)
plt.show()

print np.amax(y);
print np.amin(y);

print np.amax(ip);
print np.amin(ip);
# Out:
# -0.5007207968343514
# -0.5248459709515234
# 0.9946580773003891
# 0.02883189334680958
