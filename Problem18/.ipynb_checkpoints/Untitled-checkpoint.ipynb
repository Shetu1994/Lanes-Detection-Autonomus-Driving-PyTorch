# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Basic Main Variable Declarations
w1=1;
w2=0.5;
bias=0;
delta=0.003;


def sigma_neuron(x,ddt=False):
    if(ddt==True):
        return x*(1-x)
    return 1/(1+np.exp(-x))

def sigmoid(x):
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a



if __name__ == '__main__':
    np.random.seed(1232343242);
    data_length_x = 100;
    x = np.random.random([1,data_length_x]);
    y = sigma_neuron(w1*x+bias);
    Xaxis = np.arange(-10., 10., 0.2)
    sig = sigmoid(Xaxis)
    plt.plot(Xaxis,sig)
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Basic Main Variable Declarations
w1=0.01;
w2=1;
bias=0;
data_length_x = 100;


def sigma_neuron(x,ddt=False):
    if(ddt==True):
        return x*(1-x)
    return 1/(1+np.exp(-x))



np.random.seed(1232343242);

#inputs
Xaxis = np.arange(-10., 10., 0.2)
x = np.random.random(data_length_x);
ip= Xaxis;

y = w2*sigma_neuron(w1*ip+bias);
plt.plot(ip,y)
plt.show()
